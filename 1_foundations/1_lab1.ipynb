# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenRouter API Key exists and begins sk-or-v1

# %%
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

# openai = OpenAI()
openrouter = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

# messages = [{"role": "user", "content": "What is 2+2?"}]

response = openrouter.chat.completions.create(model="z-ai/glm-4.5-air:free", messages=[{"role":"user", "content": "what is 2+2?"}])

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

# response = openai.chat.completions.create(
#     model="gpt-4.1-nano",
#     messages=messages
# )

# print(response.choices[0].message.content)
print(response.choices[0].message.content)
# Out:
# The sum of 2 and 2 is 4. This is a basic arithmetic operation where adding two identical numbers (each being 2) results in twice the value, which is 4.
#
# **Calculation**:
# 2 + 2 = 4
#
# **Explanation**:
# - Start with the first number: 2
# - Add the second number: + 2
# - Total: 4
#
# This result is consistent across standard mathematical operations.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

# response = openai.chat.completions.create(
#     model="gpt-4.1-mini",
#     messages=messages
# )
response = openrouter.chat.completions.create(
    model="z-ai/glm-4.5-air:free", 
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# What is the next number in the sequence: 2, 3, 6, 18, 108, 1944, ...?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openrouter.chat.completions.create(
    model="z-ai/glm-4.5-air:free", 
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# The sequence is defined such that each term starting from the third term is the product of the two preceding terms. Given the sequence: 2, 3, 6, 18, 108, 1944, ...
#
# - The first term is \(a_1 = 2\).
# - The second term is \(a_2 = 3\).
# - The third term is \(a_3 = a_1 \times a_2 = 2 \times 3 = 6\).
# - The fourth term is \(a_4 = a_2 \times a_3 = 3 \times 6 = 18\).
# - The fifth term is \(a_5 = a_3 \times a_4 = 6 \times 18 = 108\).
# - The sixth term is \(a_6 = a_4 \times a_5 = 18 \times 108 = 1944\).
#
# To find the seventh term, \(a_7\), multiply the fifth and sixth terms:
# \[a_7 = a_5 \times a_6 = 108 \times 1944.\]
#
# Calculating the product:
# \[108 \times 1944 = 209952.\]
#
# Thus, the next number in the sequence is 209952.
#
# This pattern is consistent with all given terms:
# - \(a_3 = 2 \times 3 = 6\),
# - \(a_4 = 3 \times 6 = 18\),
# - \(a_5 = 6 \times 18 = 108\),
# - \(a_6 = 18 \times 108 = 1944\),
# - \(a_7 = 108 \times 1944 = 209952\).
#
# The sequence grows rapidly, but the multiplicative pattern holds for all terms.
#
# \boxed{209952}

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# The sequence is defined such that each term starting from the third term is the product of the two preceding terms. Given the sequence: 2, 3, 6, 18, 108, 1944, ...
#
# - The first term is \(a_1 = 2\).
# - The second term is \(a_2 = 3\).
# - The third term is \(a_3 = a_1 \times a_2 = 2 \times 3 = 6\).
# - The fourth term is \(a_4 = a_2 \times a_3 = 3 \times 6 = 18\).
# - The fifth term is \(a_5 = a_3 \times a_4 = 6 \times 18 = 108\).
# - The sixth term is \(a_6 = a_4 \times a_5 = 18 \times 108 = 1944\).
#
# To find the seventh term, \(a_7\), multiply the fifth and sixth terms:
# \[a_7 = a_5 \times a_6 = 108 \times 1944.\]
#
# Calculating the product:
# \[108 \times 1944 = 209952.\]
#
# Thus, the next number in the sequence is 209952.
#
# This pattern is consistent with all given terms:
# - \(a_3 = 2 \times 3 = 6\),
# - \(a_4 = 3 \times 6 = 18\),
# - \(a_5 = 6 \times 18 = 108\),
# - \(a_6 = 18 \times 108 = 1944\),
# - \(a_7 = 108 \times 1944 = 209952\).
#
# The sequence grows rapidly, but the multiplicative pattern holds for all terms.
#
# \boxed{209952}

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:
question = "pick a business area that might be worth exploring for an Agentic AI opportunity"

messages = [{"role": "user", "content": question}]

# Then make the first call:

response = openrouter.chat.completions.create(
    model="z-ai/glm-4.5-air:free", 
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message
display(Markdown(business_idea))
# Out:
# Based on current trends in AI capabilities and market needs, **Industrial Manufacturing & Smart Factory Operations** stands out as a prime area for Agentic AI opportunities. Here's why it's compelling and what specific applications make it promising:
#
# ### Why Industrial Manufacturing?
# 1.  **High Complexity & Interdependence:** Modern factories involve intricate interactions between machines, materials, humans, processes, and supply chains. Agentic AI can navigate this complexity autonomously.
# 2.  **Massive Data Generation:** Sensors, IoT devices, SCADA systems, and MES generate vast amounts of real-time data. Agentic AI can extract actionable insights *and act* on them continuously.
# 3.  **Critical Pain Points:** Manufacturers face constant pressure to:
#     *   **Maximize Uptime:** Minimize costly unplanned downtime.
#     *   **Optimize Efficiency:** Reduce energy consumption, material waste, and changeover times.
#     *   **Ensure Quality:** Detect defects early and maintain consistency.
#     *   **Enhance Flexibility:** Adapt quickly to demand fluctuations or supply chain disruptions.
#     *   **Improve Safety:** Proactively identify and mitigate workplace hazards.
# 4.  **Industry 4.0 Readiness:** Significant investments are being made in digitalization, creating infrastructure (IoT, cloud, edge computing) that Agentic AI can leverage.
# 5.  **High Stakes & ROI:** Even small improvements in efficiency or uptime translate into multi-million dollar savings for large manufacturers, justifying AI investment.
#
# ### Specific Agentic AI Opportunities in Manufacturing
#
# 1.  **Autonomous Production Line Optimization:**
#     *   **The Agent:** Continuously monitors real-time data (machine status, material flow, order priorities, quality checks).
#     *   **Actions:** Dynamically adjusts machine speeds, schedules tasks, reroutes materials, prioritizes orders, triggers preventive maintenance *without human intervention* to maximize throughput and efficiency while meeting constraints (quality, safety).
#
# 2.  **Predictive & Prescriptive Maintenance Orchestration:**
#     *   **The Agent:** Analyzes sensor data (vibration, temperature, power draw) and historical maintenance records.
#     *   **Actions:** Predicts failures *before* they cause downtime. *Autonomously* schedules maintenance, orders spare parts, reassigns personnel, and temporarily adjusts production schedules to minimize impact. It becomes the "maintenance coordinator."
#
# 3.  **Supply Chain Resilience & Logistics Agent:**
#     *   **The Agent:** Monitors inventory levels, supplier performance, transit times, and demand forecasts.
#     *   **Actions:** Proactively identifies potential shortages or delays. *Autonomously* places orders with alternative suppliers, adjusts production schedules based on material availability, re-routes shipments, and communicates changes across the supply network. It becomes the "supply chain crisis manager."
#
# 4.  **Quality Assurance & Defect Response Agent:**
#     *   **The Agent:** Integrates with vision systems, sensor data, and production line data in real-time.
#     *   **Actions:** Instantly detects anomalies or defects. *Autonomously* flags the specific unit, isolates it from the line, initiates root cause analysis (potentially triggering additional sensors/tests), adjusts downstream processes if a defect type is identified, and provides real-time feedback to operators/maintenance.
#
# 5.  **Energy Optimization Agent:**
#     *   **The Agent:** Monitors energy consumption across all equipment, processes, and environmental conditions.
#     *   **Actions:** Identifies wasteful patterns (e.g., idling machines, inefficient HVAC settings). *Autonomously* adjusts machine operating modes, schedules energy-intensive tasks off-peak, optimizes HVAC settings based on occupancy and production needs, and identifies equipment for upgrade/replacement based on energy waste.
#
# 6.  **Workforce Safety & Ergonomics Agent:**
#     *   **The Agent:** Integrates with wearable sensors, computer vision, and environmental sensors.
#     *   **Actions:** Detects unsafe behaviors (e.g., lack of PPE, improper lifting, entering restricted zones) or hazardous conditions (e.g., gas leaks, high noise). *Autonomously* issues real-time alerts, triggers safety protocols (e.g., machine shutdowns), adjusts workflows to reduce ergonomic strain, and compiles safety reports.
#
# ### Key Advantages of Agentic AI Here (Beyond Traditional Automation/Predictive Analytics)
#
# *   **Proactive, Not Reactive:** Doesn't just predict problems; *acts* to prevent them or mitigate impact in real-time.
# *   **Holistic Optimization:** Considers the *entire* system (machines, materials, people, energy, quality) simultaneously, finding global optima that isolated systems miss.
# *   **Adaptive:** Continuously learns from new data and changing conditions, refining its actions over time.
# *   **Reduced Latency:** Decisions and actions happen at machine speed, eliminating human delays.
# *   **Handles Unforeseen Events:** Can dynamically react to novel situations (e.g., a sudden machine failure, a supplier going bankrupt) that weren't explicitly programmed for.
#
# ### Challenges to Consider
#
# *   **Integration Complexity:** Connecting with diverse legacy systems (MES, SCADA, ERP, IoT platforms) is non-trivial.
# *   **Data Quality & Silos:** Requires clean, accessible, integrated data across the factory.
# *   **Safety & Reliability:** Ensuring autonomous actions are safe, reliable, and don't cause unintended consequences is paramount. Strict validation and testing are needed.
# *   **Change Management:** Requires significant workforce training and cultural shifts towards trust in AI agents.
# *   **Initial Cost:** Development and deployment require upfront investment.
#
# ### Conclusion
#
# Industrial manufacturing presents a perfect storm of complexity, valuable data, critical pain points, and a willingness to invest in advanced technology. Agentic AI moves beyond simple analytics or fixed automation towards **truly autonomous operation** – continuously perceiving, reasoning, and acting to optimize the entire factory ecosystem in real-time. The potential for massive cost savings, increased resilience, and enhanced safety makes this a highly compelling and lucrative frontier for Agentic AI development. Success here would be transformative for the industry and a powerful demonstration of Agentic AI's potential.

# %%
# First create the messages:
question = "present a pain-point in that industry - something challenging that might be ripe for an Agentic solution"

messages = [{"role": "user", "content": question}]

# Then make the first call:

response = openrouter.chat.completions.create(
    model="z-ai/glm-4.5-air:free", 
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message
display(Markdown(business_idea))
# Out:
# Here's a significant pain point in the **Healthcare Industry** that's ripe for an **Agentic Solution**:
#
# **Pain Point: Clinical Documentation Overload & Information Fragmentation**
#
# *   **The Problem:** Healthcare professionals (especially physicians, nurses, and specialists) are drowning in the administrative burden of clinical documentation. Electronic Health Records (EHRs) were intended to streamline this, but often become cumbersome data-entry systems requiring significant manual input. Clinicians spend **50% or more of their time** on documentation, leading to:
#     *   **Burnout & Job Dissatisfaction:** Constant typing and clicking detracts from patient interaction and clinical reasoning.
#     *   **Reduced Patient Time:** Less face-to-face time with patients due to administrative pressures.
#     *   **Cognitive Load & Errors:** Juggling patient care *and* complex documentation increases the risk of errors in both.
#     *   **Inconsistent & Incomplete Notes:** Manual entry is prone to omissions, inconsistencies, and lack of context, impacting care continuity and billing accuracy.
#     *   **Information Silos:** Critical insights, observations, or nuances captured during patient encounters (e.g., subtle mood changes, unspoken concerns) are often lost in structured EHR fields or buried in lengthy notes, making them hard to retrieve and utilize effectively by other providers or AI tools.
#     *   **Inefficient Workflows:** Capturing data, summarizing encounters, assigning billing codes, and generating reports are often handled by separate, disconnected tools requiring manual handoffs and context switching.
#
# *   **Why Traditional AI Falls Short:**
#     *   **Passive Tools:** Current AI solutions (like scribes or auto-summarizers) often require constant prompting, manual correction, or work *after* the fact (e.g., post-visit summarization). They don't *proactively* assist *during* the complex, dynamic flow of a patient encounter.
#     *   **Context Blindness:** They struggle to understand the full clinical context, unspoken nuances, and the clinician's evolving focus in real-time. They capture what's *said*, not necessarily what's *implied* or *clinically relevant* at that moment.
#     *   **Task-Specific:** Each tool handles one task (e.g., dictation, coding, summary creation) but doesn't *orchestrate* the entire documentation workflow or anticipate the clinician's next needs.
#     *   **Static Knowledge:** They rely on pre-trained models and struggle with real-time integration of new patient data, evolving clinical guidelines, or institutional protocols during an encounter.
#
# *   **Why an Agentic Solution is Ripe:**
#     An **Agentic Clinical Documentation Assistant (ACDA)** could be transformative by acting as a **proactive, context-aware, collaborative partner**:
#
#     *   **Real-Time Contextual Assistance:** The agent listens *during* the patient encounter (via ambient capture or integration with clinician input) and **proactively** identifies key elements: chief complaints, relevant history, exam findings, differential diagnoses, plans, medications, patient concerns. It doesn't just transcribe; it **understands intent and clinical significance** in the moment.
#     *   **Dynamic Workflow Orchestration:** The agent **autonomously** manages the documentation process:
#         *   Drafts structured notes in the EHR *as the encounter unfolds*, updating in real-time.
#         *   Suggests relevant ICD-10/CPT codes based on the evolving conversation and clinical findings.
#         *   Flags potential drug interactions or allergies based on the documented plan.
#         *   Automatically populates required fields for specific encounter types (e.g., physical exams, consults).
#         *   Summarizes key points for the clinician at natural pause points.
#     *   **Information Synthesis & Context Bridging:** The agent **synthesizes** disparate pieces of information gathered during the encounter (symptoms, vitals, lab results, patient statements, clinician observations) into a cohesive narrative. It **anticipates** what information might be needed next (e.g., "Would you like me to pull the previous echo report?").
#     *   **Learning & Adaptation:** The agent learns the clinician's documentation style, preferences, and specialty nuances over time. It integrates with institutional protocols and guidelines, updating its knowledge base dynamically. It can even ask clarifying questions *if needed* ("Did you mean 'shortness of breath' or 'chest tightness'?").
#     *   **Reduced Cognitive Load:** By handling the *mechanics* of documentation and proactively surfacing relevant information, the agent frees the clinician to focus entirely on the patient, building rapport, and complex clinical reasoning.
#
# *   **Potential Benefits:**
#     *   **Drastic Reduction in Admin Time:** Freeing up 50%+ of documentation time.
#     *   **Improved Clinician Well-being & Job Satisfaction:** Focus on patient care, less burnout.
#     *   **Enhanced Patient Experience:** More meaningful interactions, better eye contact.
#     *   **More Accurate & Complete Documentation:** Reduced errors, better coding, richer data.
#     *   **Improved Information Accessibility:** Contextual summaries and synthesized insights for the entire care team.
#     *   **Faster Care Continuity:** Notes are complete and usable immediately post-encounter.
#     *   **Actionable Data Generation:** High-quality, structured data becomes readily available for research, population health, and operational analytics.
#
# **In essence:** The pain isn't just *having* to document; it's the **cognitive overload, time sink, and fragmentation** of capturing complex clinical information accurately and efficiently *during* the demanding act of patient care. An agentic solution moves beyond passive automation to become a **proactive, intelligent partner** that understands the clinical context, orchestrates the workflow, and ultimately **restores the clinician's focus where it matters most – the patient.** This is a complex, multi-faceted problem perfectly suited for the autonomous, adaptive, and collaborative nature of AI agents.
